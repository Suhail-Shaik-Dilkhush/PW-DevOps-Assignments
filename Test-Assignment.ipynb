# %% [markdown]
# 1. Test Question ?
#    - This is a test answer for testing the google collab
#
# 2. Test Question 2 ?
#   - Trying out the google collab. need to
#   learn more about it

# %%
# Q : Test question of python to add 2 numbers

a = int(input("number 1: "))
b = int(input("number 2: "))
result = a + b
print (f"The addition of a and b is {result}") #or can be print("Addition is", a + b)
# Out:
# number 1: 1
# number 2: 2
# The addition of a and b is 3
